# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/Financial Risk Classification Dataset.csv")

df.head()
# Out:
#    age  annual_income  education_years  work_experience_years  credit_score  \
# 0   19   51140.401281               10                     21    724.748104
# 1   24   69028.631473                8                     19    655.666339
# 2   44   55186.372954               10                      1    821.874508
# 3   31   61403.651502               12                     16    715.445294
# 4   31   42536.559850                9                     19    850.000000
#
#     loan_amount  loan_duration_months  interest_rate  debt_to_income_ratio  \
# 0   3899.654973                    60       9.577176              0.733655
# 1  21084.032813                    48       8.383830              0.798551
# 2  28297.796011                    24       7.321765              0.454056
# 3  38358.635271                    12       5.997473              0.579187
# 4  46599.675272                    36       9.115591              0.135722
#
#    monthly_expenses  ...  marital_status_score  health_risk_index  \
# 0       2704.161100  ...                     3           0.692560
# 1       2611.106393  ...                     1           0.469194
# 2       2442.756164  ...                     1           0.001102
# 3       2369.382349  ...                     2           0.753590
# 4       2052.929537  ...                     1           0.364849
#
#    insurance_coverage_score  spending_score  online_activity_score  \
# 0                         3              68                     12
# 1                         3              62                      5
# 2                         2              20                     16
# 3                         2              65                     80
# 4                         5              98                     96
#
#    device_usage_hours  location_risk_index  previous_default_count  \
# 0            7.289109             0.540080                       1
# 1            5.108674             0.007390                       0
# 2            2.906073             0.704191                       1
# 3            2.938127             0.701259                       0
# 4            5.440193             0.524457                       0
#
#    financial_literacy_score  loan_default
# 0                        68             0
# 1                        92             0
# 2                        52             0
# 3                        88             0
# 4                        58             0
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (5000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         5000 non-null   int64
#  1   annual_income               5000 non-null   float64
#  2   education_years             5000 non-null   int64
#  3   work_experience_years       5000 non-null   int64
#  4   credit_score                5000 non-null   float64
#  5   loan_amount                 5000 non-null   float64
#  6   loan_duration_months        5000 non-null   int64
#  7   interest_rate               5000 non-null   float64
#  8   debt_to_income_ratio        5000 non-null   float64
#  9   monthly_expenses            5000 non-null   float64
#  10  savings_balance             5000 non-null   float64
#  11  investment_balance          5000 non-null   float64
#  12  number_of_dependents        5000 non-null   int64
#  13  employment_stability_years  5000 non-null   int64
#  14  housing_status_score        5000 non-null   int64
#  15  marital_status_score        5000 non-null   int64
#  16  health_risk_index           5000 non-null   float64
#  17  insurance_coverage_score    5000 non-null   int64
#  18  spending_score              5000 non-null   int64
#  19  online_activity_score       5000 non-null   int64
#  20  device_usage_hours          5000 non-null   float64
#  21  location_risk_index         5000 non-null   float64
#  22  previous_default_count      5000 non-null   int64
#  23  financial_literacy_score    5000 non-null   int64
#  24  loan_default                5000 non-null   int64
# dtypes: float64(11), int64(14)
# memory usage: 976.7 KB

# %%
df.columns
# Out:
# Index(['age', 'annual_income', 'education_years', 'work_experience_years',
#        'credit_score', 'loan_amount', 'loan_duration_months', 'interest_rate',
#        'debt_to_income_ratio', 'monthly_expenses', 'savings_balance',
#        'investment_balance', 'number_of_dependents',
#        'employment_stability_years', 'housing_status_score',
#        'marital_status_score', 'health_risk_index', 'insurance_coverage_score',
#        'spending_score', 'online_activity_score', 'device_usage_hours',
#        'location_risk_index', 'previous_default_count',
#        'financial_literacy_score', 'loan_default'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age                           0
# annual_income                 0
# education_years               0
# work_experience_years         0
# credit_score                  0
# loan_amount                   0
# loan_duration_months          0
# interest_rate                 0
# debt_to_income_ratio          0
# monthly_expenses              0
# savings_balance               0
# investment_balance            0
# number_of_dependents          0
# employment_stability_years    0
# housing_status_score          0
# marital_status_score          0
# health_risk_index             0
# insurance_coverage_score      0
# spending_score                0
# online_activity_score         0
# device_usage_hours            0
# location_risk_index           0
# previous_default_count        0
# financial_literacy_score      0
# loan_default                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#                age  annual_income  education_years  work_experience_years  \
# count  5000.000000    5000.000000      5000.000000             5000.00000
# mean     41.013800   60165.316248        13.492600               19.54480
# std      13.451669   15144.023201         3.448525               11.44873
# min      18.000000   15000.000000         8.000000                0.00000
# 25%      29.000000   49760.711426        10.000000               10.00000
# 50%      41.000000   60079.300451        13.000000               20.00000
# 75%      53.000000   70323.447053        17.000000               29.00000
# max      64.000000  124279.331912        19.000000               39.00000
#
#        credit_score   loan_amount  loan_duration_months  interest_rate  \
# count   5000.000000   5000.000000            5000.00000    5000.000000
# mean     679.749638  25017.723237              36.07680      10.498878
# std       58.926659  11758.762374              17.13929       4.333477
# min      472.273265   1000.000000              12.00000       3.007391
# 25%      638.926975  16893.125095              24.00000       6.803467
# 50%      679.377059  24665.287323              36.00000      10.469467
# 75%      719.961457  33099.337250              48.00000      14.267566
# max      850.000000  65468.608043              60.00000      17.996729
#
#        debt_to_income_ratio  monthly_expenses  ...  marital_status_score  \
# count           5000.000000       5000.000000  ...           5000.000000
# mean               0.474845       2491.020854  ...              1.992600
# std                0.247662        799.721575  ...              0.816504
# min                0.050072        300.000000  ...              1.000000
# 25%                0.259268       1949.191002  ...              1.000000
# 50%                0.476113       2477.942181  ...              2.000000
# 75%                0.689688       3032.498218  ...              3.000000
# max                0.899764       5295.999796  ...              3.000000
#
#        health_risk_index  insurance_coverage_score  spending_score  \
# count        5000.000000               5000.000000     5000.000000
# mean            0.499794                  2.971000       50.523600
# std             0.291004                  1.404049       28.741932
# min             0.000084                  1.000000        1.000000
# 25%             0.239153                  2.000000       26.000000
# 50%             0.508279                  3.000000       50.000000
# 75%             0.749022                  4.000000       75.000000
# max             0.999784                  5.000000      100.000000
#
#        online_activity_score  device_usage_hours  location_risk_index  \
# count            5000.000000         5000.000000          5000.000000
# mean               50.706400            6.226375             0.505953
# std                28.474739            3.319219             0.289312
# min                 1.000000            0.502232             0.000068
# 25%                26.000000            3.351673             0.250350
# 50%                51.000000            6.184174             0.510482
# 75%                75.000000            9.080226             0.754968
# max               100.000000           11.997336             0.999952
#
#        previous_default_count  financial_literacy_score  loan_default
# count             5000.000000               5000.000000   5000.000000
# mean                 0.484000                 50.869800      0.000200
# std                  0.692994                 28.795901      0.014142
# min                  0.000000                  1.000000      0.000000
# 25%                  0.000000                 26.000000      0.000000
# 50%                  0.000000                 51.000000      0.000000
# 75%                  1.000000                 76.000000      0.000000
# max                  5.000000                100.000000      1.000000
#
# [8 rows x 25 columns]

# %%
df['loan_default'].value_counts()
# Out:
# loan_default
# 0    4999
# 1       1
# Name: count, dtype: int64

# %%
#Correlation Heatmap
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
#Credit Score Distribution
sns.histplot(df['credit_score'])
plt.show()

# %%
#Annual Income vs Default
sns.boxplot(
    x='loan_default',
    y='annual_income',
    data=df
)
plt.show()

# %%
df.to_csv("../data/cleaned_data.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("../data/Financial Risk Classification Dataset.csv")

print(df["loan_default"].value_counts())
# Out:
# loan_default
# 0    4999
# 1       1
# Name: count, dtype: int64
